# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 3 데이터셋 로드

# %%
# 기본적인 통계, 분포, 결측치

# %%
df = pd.read_csv('data/mental_health_data.csv')
df.shape
# Out:
# (13200, 23)

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc DataSource          Topic  \
# 0       2018     2018           NV       Nevada      BRFSS  Mental Health
# 1       2020     2020           NV       Nevada      BRFSS  Mental Health
# 2       2018     2018           NV       Nevada      BRFSS  Mental Health
# 3       2019     2019           NV       Nevada      BRFSS  Mental Health
# 4       2017     2017           NV       Nevada      BRFSS  Mental Health
#
#                                             Question DataValueUnit  \
# 0  At least 14 recent mentally unhealthy days amo...             %
# 1  Recent mentally unhealthy days among adults ag...        Number
# 2  Recent mentally unhealthy days among adults ag...        Number
# 3  Recent mentally unhealthy days among adults ag...        Number
# 4  Recent mentally unhealthy days among adults ag...        Number
#
#        DataValueType  DataValue  ...  HighConfidenceLimit  \
# 0   Crude Prevalence       21.6  ...                 26.8
# 1               Mean        4.1  ...                  5.8
# 2               Mean        5.0  ...                  5.6
# 3  Age-adjusted Mean        4.7  ...                  5.2
# 4               Mean        3.5  ...                  3.9
#
#   StratificationCategory1      Stratification1  \
# 0                 Overall              Overall
# 1          Race/Ethnicity  Black, non-Hispanic
# 2                  Gender               Female
# 3                 Overall              Overall
# 4                 Overall              Overall
#
#                                       GeoLocation LocationID TopicID  \
# 0  POINT (-117.07184056399967 39.493240390000494)         32     MTH
# 1  POINT (-117.07184056399967 39.493240390000494)         32     MTH
# 2  POINT (-117.07184056399967 39.493240390000494)         32     MTH
# 3  POINT (-117.07184056399967 39.493240390000494)         32     MTH
# 4  POINT (-117.07184056399967 39.493240390000494)         32     MTH
#
#   QuestionID  DataValueTypeID StratificationCategoryID1 StratificationID1
# 0     MTH2_0          CRDPREV                   OVERALL               OVR
# 1     MTH1_0             MEAN                      RACE               BLK
# 2     MTH1_0             MEAN                    GENDER              GENF
# 3     MTH1_0       AGEADJMEAN                   OVERALL               OVR
# 4     MTH1_0             MEAN                   OVERALL               OVR
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  13200 non-null  int64
#  1   YearEnd                    13200 non-null  int64
#  2   LocationAbbr               13200 non-null  object
#  3   LocationDesc               13200 non-null  object
#  4   DataSource                 13200 non-null  object
#  5   Topic                      13200 non-null  object
#  6   Question                   13200 non-null  object
#  7   DataValueUnit              13200 non-null  object
#  8   DataValueType              13200 non-null  object
#  9   DataValue                  10716 non-null  float64
#  10  DataValueAlt               10716 non-null  float64
#  11  DatavalueFootnote          2561 non-null   object
#  12  LowConfidenceLimit         10716 non-null  float64
#  13  HighConfidenceLimit        10716 non-null  float64
#  14  StratificationCategory1    13200 non-null  object
#  15  Stratification1            13200 non-null  object
#  16  GeoLocation                13122 non-null  object
#  17  LocationID                 13200 non-null  int64
#  18  TopicID                    13200 non-null  object
#  19  QuestionID                 13200 non-null  object
#  20  DataValueTypeID            13200 non-null  object
#  21  StratificationCategoryID1  13200 non-null  object
#  22  StratificationID1          13200 non-null  object
# dtypes: float64(4), int64(3), object(16)
# memory usage: 2.3+ MB

# %%
# 결측치

df_null=df.isnull()
df_null.head()
# 깨끗
# Out:
#    YearStart  YearEnd  LocationAbbr  LocationDesc  DataSource  Topic  \
# 0      False    False         False         False       False  False
# 1      False    False         False         False       False  False
# 2      False    False         False         False       False  False
# 3      False    False         False         False       False  False
# 4      False    False         False         False       False  False
#
#    Question  DataValueUnit  DataValueType  DataValue  ...  \
# 0     False          False          False      False  ...
# 1     False          False          False      False  ...
# 2     False          False          False      False  ...
# 3     False          False          False      False  ...
# 4     False          False          False      False  ...
#
#    HighConfidenceLimit  StratificationCategory1  Stratification1  GeoLocation  \
# 0                False                    False            False        False
# 1                False                    False            False        False
# 2                False                    False            False        False
# 3                False                    False            False        False
# 4                False                    False            False        False
#
#    LocationID  TopicID  QuestionID  DataValueTypeID  \
# 0       False    False       False            False
# 1       False    False       False            False
# 2       False    False       False            False
# 3       False    False       False            False
# 4       False    False       False            False
#
#    StratificationCategoryID1  StratificationID1
# 0                      False              False
# 1                      False              False
# 2                      False              False
# 3                      False              False
# 4                      False              False
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#           YearStart       YearEnd    DataValue  DataValueAlt  \
# count  13200.000000  13200.000000  10716.00000   10716.00000
# mean    2015.979167   2015.979167      6.74804       6.74804
# std        3.172196      3.172196      5.47081       5.47081
# min     2011.000000   2011.000000      1.20000       1.20000
# 25%     2013.000000   2013.000000      3.60000       3.60000
# 50%     2016.000000   2016.000000      4.40000       4.40000
# 75%     2019.000000   2019.000000      6.40000       6.40000
# max     2021.000000   2021.000000     41.20000      41.20000
#
#        LowConfidenceLimit  HighConfidenceLimit    LocationID
# count        10716.000000         10716.000000  13200.000000
# mean             5.244336             8.495502     31.515227
# std              4.131193             7.545289     18.253692
# min              0.700000             1.800000      1.000000
# 25%              3.000000             4.200000     17.000000
# 50%              3.700000             5.100000     31.000000
# 75%              4.900000             8.700000     45.000000
# max             27.800000            59.400000     78.000000

# %% [markdown]
# # 4 학습 예측 데이터셋 만들기

# %%
# X : feature  y : label값
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
#        'DataValueAlt', 'DatavalueFootnote', 'LowConfidenceLimit',
#        'HighConfidenceLimit', 'StratificationCategory1', 'Stratification1',
#        'GeoLocation', 'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
#        'StratificationCategoryID1', 'StratificationID1'],
#       dtype='object')

# %%
X = df[['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
       'Topic', 'Question', 'DataValueUnit', 'DataValueType', 'DataValue',
       'DataValueAlt', 'DatavalueFootnote', 'LowConfidenceLimit', 'StratificationCategory1', 'Stratification1',
       'GeoLocation', 'LocationID', 'TopicID', 'QuestionID', 'DataValueTypeID',
       'StratificationCategoryID1', 'StratificationID1']]
X.shape
# Out:
# (13200, 22)

# %%
## 'HighConfidenceLimit'

# %%
y=df['HighConfidenceLimit']
y.shape
# Out:
# (13200,)

# %%
# 사이킷런에서 제공하는 model_selection 의 train_test_split으로 만든다.

from sklearn.model_selection import train_test_split

# train_test_split?
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# train 세트의 문제와 정답의 데이터 수를 확인

X_train
# random_state=42 를 지우면 매번 랜덤이 되어서 똑같은 자료를 불러올 수 없으므로 지정
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 3958        2013     2013           IL        Illinois      BRFSS
# 2239        2011     2011           DE        Delaware      BRFSS
# 3608        2015     2015           IA            Iowa      BRFSS
# 6848        2017     2017           MS     Mississippi      BRFSS
# 6119        2018     2018           MN       Minnesota      BRFSS
# ...          ...      ...          ...             ...        ...
# 11964       2018     2018           VI  Virgin Islands      BRFSS
# 5191        2011     2011           MA   Massachusetts      BRFSS
# 5390        2015     2015           MD        Maryland      BRFSS
# 860         2014     2014           AR        Arkansas      BRFSS
# 7270        2021     2021           ND    North Dakota      BRFSS
#
#                Topic                                           Question  \
# 3958   Mental Health  Recent mentally unhealthy days among adults ag...
# 2239   Mental Health  Recent mentally unhealthy days among adults ag...
# 3608   Mental Health  At least 14 recent mentally unhealthy days amo...
# 6848   Mental Health  Recent mentally unhealthy days among adults ag...
# 6119   Mental Health  Recent mentally unhealthy days among adults ag...
# ...              ...                                                ...
# 11964  Mental Health  Recent mentally unhealthy days among adults ag...
# 5191   Mental Health  Recent mentally unhealthy days among adults ag...
# 5390   Mental Health  Recent mentally unhealthy days among adults ag...
# 860    Mental Health  At least 14 recent mentally unhealthy days amo...
# 7270   Mental Health  Recent mentally unhealthy days among adults ag...
#
#       DataValueUnit      DataValueType  DataValue  ...  LowConfidenceLimit  \
# 3958         Number               Mean        3.3  ...                 3.0
# 2239         Number  Age-adjusted Mean        3.4  ...                 2.0
# 3608              %   Crude Prevalence        NaN  ...                 NaN
# 6848         Number  Age-adjusted Mean        5.0  ...                 4.6
# 6119         Number  Age-adjusted Mean        2.8  ...                 2.2
# ...             ...                ...        ...  ...                 ...
# 11964        Number  Age-adjusted Mean        NaN  ...                 NaN
# 5191         Number  Age-adjusted Mean        2.1  ...                 1.5
# 5390         Number  Age-adjusted Mean        3.9  ...                 3.4
# 860               %   Crude Prevalence        NaN  ...                 NaN
# 7270         Number               Mean        3.4  ...                 3.2
#
#       StratificationCategory1      Stratification1  \
# 3958           Race/Ethnicity  White, non-Hispanic
# 2239           Race/Ethnicity             Hispanic
# 3608           Race/Ethnicity             Hispanic
# 6848                  Overall              Overall
# 6119           Race/Ethnicity             Hispanic
# ...                       ...                  ...
# 11964          Race/Ethnicity             Hispanic
# 5191           Race/Ethnicity  Other, non-Hispanic
# 5390                   Gender               Female
# 860            Race/Ethnicity             Hispanic
# 7270           Race/Ethnicity  White, non-Hispanic
#
#                                          GeoLocation LocationID TopicID  \
# 3958    POINT (-88.99771017799969 40.48501028300046)         17     MTH
# 2239   POINT (-75.57774116799965 39.008830667000495)         10     MTH
# 3608    POINT (-93.81649055599968 42.46940091300047)         19     MTH
# 6848   POINT (-89.53803082499968 32.745510099000455)         28     MTH
# 6119    POINT (-94.79420050299967 46.35564873600049)         27     MTH
# ...                                              ...        ...     ...
# 11964                   POINT (-64.896335 18.335765)         78     MTH
# 5191    POINT (-72.08269067499964 42.27687047000046)         25     MTH
# 5390    POINT (-76.60926011099963 39.29058096400047)         24     MTH
# 860     POINT (-92.27449074299966 34.74865012400045)          5     MTH
# 7270   POINT (-100.11842104899966 47.47531977900047)         38     MTH
#
#        QuestionID DataValueTypeID StratificationCategoryID1 StratificationID1
# 3958       MTH1_0            MEAN                      RACE               WHT
# 2239       MTH1_0      AGEADJMEAN                      RACE               HIS
# 3608       MTH2_0         CRDPREV                      RACE               HIS
# 6848       MTH1_0      AGEADJMEAN                   OVERALL               OVR
# 6119       MTH1_0      AGEADJMEAN                      RACE               HIS
# ...           ...             ...                       ...               ...
# 11964      MTH1_0      AGEADJMEAN                      RACE               HIS
# 5191       MTH1_0      AGEADJMEAN                      RACE               OTH
# 5390       MTH1_0      AGEADJMEAN                    GENDER              GENF
# 860        MTH2_0         CRDPREV                      RACE               HIS
# 7270       MTH1_0            MEAN                      RACE               WHT
#
# [10560 rows x 22 columns]

# %%
X_train.shape, y_train.shape
# Out:
# ((10560, 22), (10560,))

# %%
# test 세트의 문제와 정답의 데이터 수 확인
X_test.shape, y_test.shape
# Out:
# ((2640, 22), (2640,))

# %% [markdown]
# # 5 GradientBoost

# %%
from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier()
model
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# # 6 학습, 예측

# %%
# 학습

model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_46630/1793167733.py in ?()
#       1 # 학습
#       2
# ----> 3 model.fit(X_train, y_train)
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_gb.py in ?(self, X, y, sample_weight, monitor)
#     412         # Check input
#     413         # Since check_array converts both X and y to the same dtype, but the
#     414         # trees use different types for X and y, checking them separately.
#     415
# --> 416         X, y = self._validate_data(
#     417             X, y, accept_sparse=["csr", "csc", "coo"], dtype=DTYPE, multi_output=True
#     418         )
#     419
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     617                 if "estimator" not in check_y_params:
#     618                     check_y_params = {**default_check_params, **check_y_params}
#     619                 y = check_array(y, input_name="y", **check_y_params)
#     620             else:
# --> 621                 X, y = check_X_y(X, y, **check_params)
#     622             out = X, y
#     623
#     624         if not no_val_X and check_params.get("ensure_2d", True):
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1143         raise ValueError(
#    1144             f"{estimator_name} requires y to be passed, but the target y is None"
#    1145         )
#    1146
# -> 1147     X = check_array(
#    1148         X,
#    1149         accept_sparse=accept_sparse,
#    1150         accept_large_sparse=accept_large_sparse,
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     914                         )
#     915                     array = xp.astype(array, dtype, copy=False)
#     916                 else:
#     917                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 918             except ComplexWarning as complex_warning:
#     919                 raise ValueError(
#     920                     "Complex data not supported\n{}\n".format(array)
#     921                 ) from complex_warning
#
# ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     376         # Use NumPy API to support order
#     377         if copy is True:
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#     383         # container that is consistent with the input's namespace.
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'IL'
