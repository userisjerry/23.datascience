# %%
import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt


# %matplotlib inline

df=pd.read_csv('data/국민건강보험공단_건강검진정보_20211231.csv')
# encoding='cp949'
df.shape

df_sample = df.sample(1000,random_state=1)
df_sample.shape
# Out:
# (1000, 34)

# %% [markdown]
# # 15 수치형 데이터 시각화

# %% [markdown]
# ## 15.1 scatterplot-산점도
# * 수치형 / 수치형데이터의 상관관계를 볼 때 주로 사용
# * 점의 크기를 데이터의 수치에 따라 다르게 볼 수 있다

# %%
df.columns
# Out:
# Index(['HCHK_YEAR', 'IDV_ID', 'SIDO', 'SEX', 'AGE_GROUP', 'HEIGHT', 'WEIGHT',
#        'WAIST', 'SIGHT_LEFT', 'SIGHT_RIGHT', 'HEAR_LEFT', 'HEAR_RIGHT',
#        'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE',
#        'LDL_CHOLE', 'HMG', 'OLIG_PROTE_CD', 'CREATININE', 'SGOT_AST',
#        'SGPT_ALT', 'GAMMA_GTP', 'SMK_STAT_TYPE_CD', 'DRK_YN',
#        'HCHK_OE_INSPEC_YN', 'CRS_YN', 'TTH_MSS_YN', 'ODT_TRB_YN',
#        'WSDM_DIS_YN', 'TTR_YN', 'DATA_STD_DT'],
#       dtype='object')

# %%
# scatterplot으로 
# 혈청지오티 ast, alt 그리고
# 음주여부에 따라 다른 색상
plt.figure(figsize=(8,7))
sns.scatterplot(data=df_sample, x='SGOT_AST', y='SGPT_ALT', 
                hue='DRK_YN', size='WEIGHT')
# Out:
# <Axes: xlabel='SGOT_AST', ylabel='SGPT_ALT'>

# %% [markdown]
# ## 15.2 lmplot-상관관계를 보기

# %%
# lmplot으로 신장에따라
# 체중을 그리며
# 음주여부에다라 다른 색상

sns.lmplot(data=df_sample, x='HEIGHT', y='WEIGHT', hue='DRK_YN')
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df_sample, x='HEIGHT', y='WEIGHT', hue='SEX', col='DRK_YN')
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df_sample, x='HEIGHT', y='WEIGHT', hue='DRK_YN', col='DRK_YN')
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=df_sample, x='HEIGHT', y='WEIGHT', hue='DRK_YN', col='SEX')
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# lmplot의 col기능을 통해
# 음주여부에 따라 서브플롯을 그린다

sns.lmplot(data=df_sample, x='HEIGHT', y='WEIGHT', hue='SMK_STAT_TYPE_CD', col='DRK_YN')
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# lmplot으로 수축기, 이완기혈압을 그리고
# 음주여부에 따라 다른 색상

plt.figure(figsize=(4,4))
sns.lmplot(data=df_sample, x='SGOT_AST', y='SGPT_ALT', hue='DRK_YN')

sns.lmplot(data=df_sample, x='SGOT_AST', y='SGPT_ALT')
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['HCHK_YEAR', 'IDV_ID', 'SIDO', 'SEX', 'AGE_GROUP', 'HEIGHT', 'WEIGHT',
#        'WAIST', 'SIGHT_LEFT', 'SIGHT_RIGHT', 'HEAR_LEFT', 'HEAR_RIGHT',
#        'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE',
#        'LDL_CHOLE', 'HMG', 'OLIG_PROTE_CD', 'CREATININE', 'SGOT_AST',
#        'SGPT_ALT', 'GAMMA_GTP', 'SMK_STAT_TYPE_CD', 'DRK_YN',
#        'HCHK_OE_INSPEC_YN', 'CRS_YN', 'TTH_MSS_YN', 'ODT_TRB_YN',
#        'WSDM_DIS_YN', 'TTR_YN', 'DATA_STD_DT'],
#       dtype='object')

# %%
# lmplot으로
# ast, alt 그리고
# 음주여부에 다른 색상

sns.lmplot(data=df_sample, x='SGOT_AST', y='SGPT_ALT', 
           hue='DRK_YN', robust=True)
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## 15.3 이상치 다루기
# * 이상치가 있으면 데이터가 자세히 보이지 않거나
# * 이상치로 인해 회귀선이 달라지기도 합니다
# * 시각화를 통해 찾은 이상치를 제거하고 보거나
# * 이상치만 따로 모아 보도록 합니다

# %%
df.columns
# Out:
# Index(['HCHK_YEAR', 'IDV_ID', 'SIDO', 'SEX', 'AGE_GROUP', 'HEIGHT', 'WEIGHT',
#        'WAIST', 'SIGHT_LEFT', 'SIGHT_RIGHT', 'HEAR_LEFT', 'HEAR_RIGHT',
#        'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE',
#        'LDL_CHOLE', 'HMG', 'OLIG_PROTE_CD', 'CREATININE', 'SGOT_AST',
#        'SGPT_ALT', 'GAMMA_GTP', 'SMK_STAT_TYPE_CD', 'DRK_YN',
#        'HCHK_OE_INSPEC_YN', 'CRS_YN', 'TTH_MSS_YN', 'ODT_TRB_YN',
#        'WSDM_DIS_YN', 'TTR_YN', 'DATA_STD_DT'],
#       dtype='object')

# %%
# ast, alt가 400이하인 값만 
# 데이터프레임 형태로 추출해서
# df_ASLT 라는 변수에 담는다

df_ASLT = df_sample[(df_sample['SGOT_AST']<400) & (df_sample['SGPT_ALT']<400)]

# %%
# 이상치를 제거한; ci=None;  ast, alt를 lmplot으로 그리며
# 음주여부에 따라 다른색

sns.lmplot(data=df_ASLT, x='SGOT_AST', y='SGOT_ALT', hue='DRK_YN'
          ,ci=None)
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# ast, alt가 400 이상인 값만 데이터프레임 형태로 추출
# df_ASLT_high 라는 변수에 담는다

df_ASLT_high=df[(df['SGOT_AST']>=400) | (df['SGPT_ALT']>=400)]

# %%
df_ASLT_high
# Out:
#         HCHK_YEAR   IDV_ID  SIDO  SEX  AGE_GROUP  HEIGHT  WEIGHT  WAIST  \
# 8058         2021   888488    41    2         12     160      65   76.0
# 8153         2021  2470972    41    2         13     145      35   70.0
# 15435        2021  3868401    41    2         11     160      55   69.0
# 15587        2021  4628288    41    2         11     155      60   86.0
# 16285        2021  2069369    41    2         10     155      50   66.0
# ...           ...      ...   ...  ...        ...     ...     ...    ...
# 999876       2021  3746883    44    1          9     165      80   92.0
# 999883       2021  3006329    41    2         12     155      60   78.0
# 999967       2021  4754540    42    1         12     170      70   86.0
# 999974       2021  3536251    48    2         10     160      70   77.0
# 999991       2021  1499980    42    2         11     155      45   69.0
#
#         SIGHT_LEFT  SIGHT_RIGHT  ...  GAMMA_GTP  SMK_STAT_TYPE_CD  DRK_YN  \
# ...

# %%
# 위에서 구한 df_ASLT_high 데이터 프레임에 담겨진
# 혈청지오티가 높은 데이터만 따로 본다

sns.lmplot(data=df_ASLT_high, x='SGOT_AST', y='SGPT_ALT', hue='DRK_YN'
          ,ci=None)
# Out:
# /Users/yuri/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_ASLT_high_8000=df_ASLT_high[df_ASLT_high['SGOT_AST']>8000]
df_ASLT_high_8000.iloc[:,4:27]
# Out:
#         AGE_GROUP  HEIGHT  WEIGHT  WAIST  SIGHT_LEFT  SIGHT_RIGHT  HEAR_LEFT  \
# 998131          9     180      75   88.0         0.0          0.0        2.0
#
#         HEAR_RIGHT  BP_HIGH  BP_LWST  ...  HDL_CHOLE  LDL_CHOLE   HMG  \
# 998131         1.0    112.0     85.0  ...       40.0       31.0  16.0
#
#         OLIG_PROTE_CD  CREATININE  SGOT_AST  SGPT_ALT  GAMMA_GTP  \
# 998131            4.0         1.0    8138.0    3244.0     1055.0
#
#         SMK_STAT_TYPE_CD  DRK_YN
# 998131               3.0     1.0
#
# [1 rows x 23 columns]

# %% [markdown]
# ## 15.4 distplot
# * 히스토그램-위키백과
# * 확률밀도함수-위키백과

# %%
# 수치형 데이터로 된 컬럼을 찾기 위해 
# 컬럼명만 따로 출력

df.columns
# Out:
# Index(['HCHK_YEAR', 'IDV_ID', 'SIDO', 'SEX', 'AGE_GROUP', 'HEIGHT', 'WEIGHT',
#        'WAIST', 'SIGHT_LEFT', 'SIGHT_RIGHT', 'HEAR_LEFT', 'HEAR_RIGHT',
#        'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE',
#        'LDL_CHOLE', 'HMG', 'OLIG_PROTE_CD', 'CREATININE', 'SGOT_AST',
#        'SGPT_ALT', 'GAMMA_GTP', 'SMK_STAT_TYPE_CD', 'DRK_YN',
#        'HCHK_OE_INSPEC_YN', 'CRS_YN', 'TTH_MSS_YN', 'ODT_TRB_YN',
#        'WSDM_DIS_YN', 'TTR_YN', 'DATA_STD_DT'],
#       dtype='object')

# %%
df[df['TOT_CHOLE'].notnull()]
df_chol = df.loc[df['TOT_CHOLE'].notnull(),'TOT_CHOLE']
df_chol.head(5)
# Out:
# 574465    172.0
# 574466    140.0
# 574467    202.0
# 574469    163.0
# 574470    180.0
# Name: TOT_CHOLE, dtype: float64

# %%
sns.distplot(df_chol)
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/2038938302.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_chol)
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
sns.distplot(df_chol, bins=1)
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/2050508859.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_chol, bins=1)
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
sns.distplot(df_chol, bins=10)
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/21038991.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_chol, bins=10)
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
sns.distplot(df_chol, bins=100)
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/2544951005.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_chol, bins=100)
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
df_chol.describe()
# Out:
# count    425059.000000
# mean        198.747915
# std          43.769043
# min          44.000000
# 25%         170.000000
# 50%         198.000000
# 75%         226.000000
# max        2625.000000
# Name: TOT_CHOLE, dtype: float64

# %%
# '총콜레스테롤' 에 따른 displot

sns.distplot(df['TOT_CHOLE'])
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/2472376808.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['TOT_CHOLE'])
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
df_chol
# Out:
# 574465    172.0
# 574466    140.0
# 574467    202.0
# 574469    163.0
# 574470    180.0
#           ...
# 999995    149.0
# 999996    195.0
# 999997    247.0
# 999998    286.0
# 999999    108.0
# Name: TOT_CHOLE, Length: 425059, dtype: float64

# %%
# Out:
# 574465    172.0
# 574466    140.0
# 574467    202.0
# 574469    163.0
# 574470    180.0
#           ...
# 999995    149.0
# 999996    195.0
# 999997    247.0
# 999998    286.0
# 999999    108.0
# Name: TOT_CHOLE, Length: 425059, dtype: float64

# %%
# 음주여부가 0인 값에 대한
# 총콜레스테롤을 distplot


df[df['TOT_CHOLE'].notnull()& df['DRK_YN']==1]
# Out:
#         HCHK_YEAR   IDV_ID  SIDO  SEX  AGE_GROUP  HEIGHT  WEIGHT  WAIST  \
# 574467       2021  3065806    41    1         10     180      80   84.0
# 574469       2021  2025357    11    1         16     165      60   84.0
# 574470       2021  1976052    41    2          9     160      50   76.0
# 574474       2021  2189649    48    2          9     165      55   69.0
# 574479       2021  1346180    47    2          9     160      65   74.0
# ...           ...      ...   ...  ...        ...     ...     ...    ...
# 999413       2021  3031178    47    2         11     155      50   77.0
# 999414       2021   719672    11    2         13     150      40   65.0
# 999415       2021  4812984    11    1         11     180      90  103.0
# 999417       2021    42621    41    2          9     150      70   92.0
# 999421       2021  2911237    46    2          9     160      70   84.0
#
#         SIGHT_LEFT  SIGHT_RIGHT  ...  GAMMA_GTP  SMK_STAT_TYPE_CD  DRK_YN  \
# ...

# %%
sns.distplot(df.loc[
    df['TOT_CHOLE'].notnull()& (df['DRK_YN']==1),'TOT_CHOLE'])
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/3954388448.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
# 음주여부가 1인 값에 대한
# 총콜레스테롤을 distplot

sns.distplot(df.loc[
    df['TOT_CHOLE'].notnull()& (df['DRK_YN']==0),'TOT_CHOLE'])
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/478729164.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
# 음주여부 값에 대한 
# 총콜레스테롤을 distplot으로 그리며
# 하나의 그래프에 표시

sns.distplot(df.loc[
    df['TOT_CHOLE'].notnull()& (df['DRK_YN']==1),'TOT_CHOLE'])
sns.distplot(df.loc[
    df['TOT_CHOLE'].notnull()& (df['DRK_YN']==0),'TOT_CHOLE'])
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/3426777827.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.loc[
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/3426777827.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#  히스토그램 뺄래
# kde

plt.axvline(df_sample['TOT_CHOLE'].mean(), linestyle=':')
plt.axvline(df_sample['TOT_CHOLE'].median(), linestyle='--')

sns.kdeplot(df.loc[
    df['TOT_CHOLE'].notnull()& (df['DRK_YN']==1),'TOT_CHOLE'], label='음주중')

sns.kdeplot(df.loc[
    df['TOT_CHOLE'].notnull()& (df['DRK_YN']==0),'TOT_CHOLE'], label='음주 안함')
#
#  label 달아보기 이넫 어디갔냐
# Out:
# <Axes: xlabel='TOT_CHOLE', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['HCHK_YEAR', 'IDV_ID', 'SIDO', 'SEX', 'AGE_GROUP', 'HEIGHT', 'WEIGHT',
#        'WAIST', 'SIGHT_LEFT', 'SIGHT_RIGHT', 'HEAR_LEFT', 'HEAR_RIGHT',
#        'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE',
#        'LDL_CHOLE', 'HMG', 'OLIG_PROTE_CD', 'CREATININE', 'SGOT_AST',
#        'SGPT_ALT', 'GAMMA_GTP', 'SMK_STAT_TYPE_CD', 'DRK_YN',
#        'HCHK_OE_INSPEC_YN', 'CRS_YN', 'TTH_MSS_YN', 'ODT_TRB_YN',
#        'WSDM_DIS_YN', 'TTR_YN', 'DATA_STD_DT'],
#       dtype='object')

# %%
# 감마지티피 값에 따라 음주여부를 시각화

df_sample['GAMMA_GTP']
# Out:
# 276826     16.0
# 849425     17.0
# 504499     18.0
# 601054     22.0
# 980221    215.0
#           ...
# 890013     83.0
# 875389     65.0
# 358458     52.0
# 808228     18.0
# 317698     39.0
# Name: GAMMA_GTP, Length: 1000, dtype: float64

# %%
sns.distplot(df_sample['GAMMA_GTP'])
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/658502006.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sample['GAMMA_GTP'])
# <Axes: xlabel='GAMMA_GTP', ylabel='Density'>

# %%
df_1 = df_sample.loc[df_sample['DRK_YN']==1, 'GAMMA_GTP']
df_0 = df_sample.loc[df_sample['DRK_YN']==0, 'GAMMA_GTP']

sns.distplot(df_1)
# Out:
# /var/folders/sp/mym89g410d75pchy52vhq7y80000gn/T/ipykernel_38623/3154473651.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1)
# <Axes: xlabel='GAMMA_GTP', ylabel='Density'>

# %%
df_1 = df_sample.loc[df_sample['DRK_YN']==1, 'GAMMA_GTP']
df_0 = df_sample.loc[df_sample['DRK_YN']==0, 'GAMMA_GTP']

sns.kdeplot(df_1, label='dffdfdfdf')
sns.kdeplot(df_0, label='lplplplplp')
# label 왜 안뜨냐고
# Out:
# <Axes: xlabel='GAMMA_GTP', ylabel='Density'>
